# %% [markdown]
# ![imagen](img/python.jpg)

# %% [markdown]
# ## GROUP PROJECT
#
# The Group Project has two parts:
#
# ### 1. First Part: Flask
#
# It is requested to have a backend in **Flask** which is an API with:
# * routes
# * parameters in the path
# * parameters in the query
# * parameters in the body
#
# The **Flask** application backend should use a Machine Learning model to make predictions.<br>
# It is mandatory to deploy it and to have a **webhook** (CI/CD).
#
# It is recommended to follow the steps learnt in class and deploy the solution in *Pythonanywhere*.<br>
# <u>Note: try at least to deploy it in Pythonanywhere.</u><br>
# You will practise the concepts and in the future you can think of other clouds.
#
#
# You have to submit the code and screenshots showing the green check in the **webhook** to prove that it works fine.<br>
#
# Comment your code.<br>
#
# **Please provide explanation of every step.<br>Even more if you are developing any additional funcionality or using other cloud.**<br> Use as a reference the steps in Advanced_Python_Session_7.ipynb giving detail of what each steps pursues, how it does it and the execution from the code or interaction with any program/cloud.
#
# The group has to **submit**:
# * README.md (markdown)
# * Data (no *big data*)
# * Python scripts (ML_model.py, ML_model.pkl)
# * requirements.txt
# * Jupyternotebook (.ipynb) with screenshots explaining every step
# * Executive presentation (to be presented on 17th March)
#
#
# ### 2. Second Part: FastAPI
#
# In this part it is <u>not mandatory</u> to deploy the solution in the cloud.<br>
# However, if you had time, you could.
#
# **Mandatory**
#
# You have to create:
#
# * Pydantic models (schemas)
# * SQLAlchemy ORM models
# * A SQLite database
# * FastAPI endpoints
# * FastAPI dependencies (dependency injection)
#
# Any extra additional material explained in the course will be **evaluated positively**.
#
# There are no FastAPI exercises because the idea is that you practise and start developing from what we are learning in FastAPI **for your INDIVIDUAL and GROUP PROJECT**.
#
# The group has to **submit**:
# * README.md (markdown)
# * requirements.txt
# * FastAPI Python project with its structure
# * Jupyternotebook (.ipynb) with screenshots explaining every step of how your application works
#
#
# **Submission**: share **one** GitHub repository from **one** member of the group with me.<br>
# The repository can be private. In that case, send me an invitation.

# %% [markdown]
# ## Individual Project
#
# **Mandatory**
#
# You have to create:
#
# * Pydantic models (schemas)
# * FastAPI endpoints
# * FastAPI dependencies (dependency injection)
# * A dummy database (dictionary)
#
# We will also take into account where we are when we are close to the deadline for the Individual Project.<br>
#
#
# Any extra additional material explained in the course, will be evaluated positively.<br>
# You can develop a sqlite database or SQLAlchemy ORM models, but it's additional.
#
# There are no FastAPI exercises because the idea is that you practise what we learn in FastAPI **for your INDIVIDUAL and GROUP PROJECT**.
#
#
# **Submission**: share one GitHub repository with me.<br>
# The repository can be private. In that case, send me an invitation.

# %% [markdown]
# ### Deadlines
#
# Group project submission **Friday 14th March**<br> available time: 6 weeks since 3rd Feb
#
# Presentation of the Group Projects **Monday 17th March**
#
# Individual project submission **Friday 21st March** (**moved!**, not on 28th March, <u>to clarify in class</u>)<br> available time: 7 weeks since 3rd Feb
#
# Exams:
#
# Final exam **Friday 21st March**
#
# Midterm exam Monday **10th February**
#
# ### Groups
#
# ![image.png](attachment:image.png)
#
# The groups will have 15 min to present and 5 min questions-answers.<br>
# **20 min maximum** so that all the groups can fit in the session.
